# %%
# Import Modules
import pandas as pd
from pathlib import Path

# %%
# Read CSV File for 2023
census_data_23 = Path("Resources/census_data_2023.csv")
census_df_23 = pd.read_csv(census_data_23)

# Display the DataFrame
census_df_23.head()

# Keep only columns that contain "Median income (dollars)!!Estimate" in their name
filtered_columns_23 = [col for col in census_df_23.columns if "Median income (dollars)!!Estimate" in col or "Label (Grouping)" in col]

# Create a new DataFrame with only the filtered columns
census_df_filtered_23 = census_df_23[filtered_columns_23]

# Check the filtered DataFrame
census_df_filtered_23.head()

# Transpose DF
census_df_filtered_t_23 = census_df_filtered_23.transpose()
census_df_filtered_t_23.columns = census_df_filtered_t_23.iloc[0]
census_df_filtered_t_23.head()

# Rename Columns by taking out extra characters
census_renamed_23 = census_df_filtered_23.rename(columns=lambda col: col.replace('!!', ''))
census_renamed_23

census_renamed_23final = census_renamed_23.rename(columns=lambda col: col.replace('Median income (dollars)Estimate', ''))
census_renamed_23final

#transpose
census_t_23 = census_renamed_23final.transpose()
census_t_23.head()
# Out:
#                                                                  0   \
# Label (Grouping)  HOUSEHOLD INCOME BY RACE AND HISPANIC OR LATIN...
# Alabama                                                         NaN
# Alaska                                                          NaN
# Arizona                                                         NaN
# Arkansas                                                        NaN
#
#                                             1                   2   \
# Label (Grouping)  2023 Median Household Income          One race--
# Alabama                                 62,212                 NaN
# Alaska                                  86,631                 NaN
# Arizona                                 77,315                 NaN
# Arkansas                                58,700                 NaN
#
#                                  3                                      4   \
# ...

# %%
census_t_23[1]
# Out:
# Label (Grouping)        2023 Median Household Income
# Alabama                                       62,212
# Alaska                                        86,631
# Arizona                                       77,315
# Arkansas                                      58,700
# California                                    95,521
# Colorado                                      92,911
# Connecticut                                   91,665
# Delaware                                      81,361
# District of Columbia                         108,210
# Florida                                       73,311
# Georgia                                       74,632
# Hawaii                                        95,322
# Idaho                                         74,942
# Illinois                                      80,306
# Indiana                                       69,477
# Iowa                                          71,433
# Kansas                                        70,333
# ...

# %%
census_23_households = census_t_23[1].reset_index()

# %%
census_23_households.columns = census_23_households.iloc[0]
census_23_households = census_23_households[1:]

# %%
census_23_households
# Out:
# 0       Label (Grouping) 2023 Median Household Income
# 1                Alabama                       62,212
# 2                 Alaska                       86,631
# 3                Arizona                       77,315
# 4               Arkansas                       58,700
# 5             California                       95,521
# 6               Colorado                       92,911
# 7            Connecticut                       91,665
# 8               Delaware                       81,361
# 9   District of Columbia                      108,210
# 10               Florida                       73,311
# 11               Georgia                       74,632
# 12                Hawaii                       95,322
# 13                 Idaho                       74,942
# 14              Illinois                       80,306
# 15               Indiana                       69,477
# 16                  Iowa                       71,433
# ...

# %%
# Read CSV File for 2022
census_data_22 = Path("Resources/census_data_2022.csv")
census_df_22 = pd.read_csv(census_data_22)

# Display the DataFrame
census_df_22.head()

# Keep only columns that contain "Median income (dollars)!!Estimate" in their name
filtered_columns_22 = [col for col in census_df_22.columns if "Median income (dollars)!!Estimate" in col or "Label (Grouping)" in col]

# Create a new DataFrame with only the filtered columns
census_df_filtered_22 = census_df_22[filtered_columns_23]

# Check the filtered DataFrame
census_df_filtered_22.head()

# Transpose DF
census_df_filtered_t_22 = census_df_filtered_22.transpose()
census_df_filtered_t_22.columns = census_df_filtered_t_22.iloc[0]
census_df_filtered_t_22.head()

# Rename Columns by taking out extra characters
census_renamed_22 = census_df_filtered_22.rename(columns=lambda col: col.replace('!!', ''))
census_renamed_22

census_renamed_22final = census_renamed_22.rename(columns=lambda col: col.replace('Median income (dollars)Estimate', ''))
census_renamed_22final

#transpose
census_t_22 = census_renamed_22final.transpose()
census_t_22.head()
# Out:
#                                                                  0   \
# Label (Grouping)  HOUSEHOLD INCOME BY RACE AND HISPANIC OR LATIN...
# Alabama                                                         NaN
# Alaska                                                          NaN
# Arizona                                                         NaN
# Arkansas                                                        NaN
#
#                                             1                   2   \
# Label (Grouping)  2022 Median Household Income          One race--
# Alabama                                 59,674                 NaN
# Alaska                                  88,121                 NaN
# Arizona                                 74,568                 NaN
# Arkansas                                55,432                 NaN
#
#                                  3                                      4   \
# ...

# %%
census_t_22[1]
# Out:
# Label (Grouping)        2022 Median Household Income
# Alabama                                       59,674
# Alaska                                        88,121
# Arizona                                       74,568
# Arkansas                                      55,432
# California                                    91,551
# Colorado                                      89,302
# Connecticut                                   88,429
# Delaware                                      82,174
# District of Columbia                         101,027
# Florida                                       69,303
# Georgia                                       72,837
# Hawaii                                        92,458
# Idaho                                         72,785
# Illinois                                      76,708
# Indiana                                       66,785
# Iowa                                          69,588
# Kansas                                        68,925
# ...

# %%
census_22_households = census_t_22[1].reset_index()

# %%
census_22_households.columns = census_22_households.iloc[0]
census_22_households = census_22_households[1:]

# %%
census_22_households
# Out:
# 0       Label (Grouping) 2022 Median Household Income
# 1                Alabama                       59,674
# 2                 Alaska                       88,121
# 3                Arizona                       74,568
# 4               Arkansas                       55,432
# 5             California                       91,551
# 6               Colorado                       89,302
# 7            Connecticut                       88,429
# 8               Delaware                       82,174
# 9   District of Columbia                      101,027
# 10               Florida                       69,303
# 11               Georgia                       72,837
# 12                Hawaii                       92,458
# 13                 Idaho                       72,785
# 14              Illinois                       76,708
# 15               Indiana                       66,785
# 16                  Iowa                       69,588
# ...

# %%
# Read CSV File for 2021
census_data_21 = Path("Resources/census_data_2021.csv")
census_df_21 = pd.read_csv(census_data_21)

# Display the DataFrame
census_df_21.head()

# Keep only columns that contain "Median income (dollars)!!Estimate" in their name
filtered_columns_21 = [col for col in census_df_21.columns if "Median income (dollars)!!Estimate" in col or "Label (Grouping)" in col]

# Create a new DataFrame with only the filtered columns
census_df_filtered_21 = census_df_21[filtered_columns_21]

# Check the filtered DataFrame
census_df_filtered_21.head()

# Transpose DF
census_df_filtered_t_21 = census_df_filtered_21.transpose()
census_df_filtered_t_21.columns = census_df_filtered_t_21.iloc[0]
census_df_filtered_t_21.head()

# Rename Columns by taking out extra characters
census_renamed_21 = census_df_filtered_21.rename(columns=lambda col: col.replace('!!', ''))
census_renamed_21

census_renamed_21final = census_renamed_21.rename(columns=lambda col: col.replace('Median income (dollars)Estimate', ''))
census_renamed_21final

#transpose
census_t_21 = census_renamed_21final.transpose()
census_t_21.head()
# Out:
#                                                                  0   \
# Label (Grouping)  HOUSEHOLD INCOME BY RACE AND HISPANIC OR LATIN...
# Alabama                                                         NaN
# Alaska                                                          NaN
# Arizona                                                         NaN
# Arkansas                                                        NaN
#
#                                             1                   2   \
# Label (Grouping)  2021 Median Household Income          One race--
# Alabama                                 53,913                 NaN
# Alaska                                  77,845                 NaN
# Arizona                                 69,056                 NaN
# Arkansas                                52,528                 NaN
#
#                                  3                                      4   \
# ...

# %%
census_t_21[1]
# Out:
# Label (Grouping)        2021 Median Household Income
# Alabama                                       53,913
# Alaska                                        77,845
# Arizona                                       69,056
# Arkansas                                      52,528
# California                                    84,907
# Colorado                                      82,254
# Connecticut                                   83,771
# Delaware                                      71,091
# District of Columbia                          90,088
# Florida                                       63,062
# Georgia                                       66,559
# Hawaii                                        84,857
# Idaho                                         66,474
# Illinois                                      72,205
# Indiana                                       62,743
# Iowa                                          65,600
# Kansas                                        64,124
# ...

# %%
census_21_households = census_t_21[1].reset_index()

# %%
census_21_households.columns = census_21_households.iloc[0]
census_21_households = census_21_households[1:]

# %%
census_21_households
# Out:
# 0       Label (Grouping) 2021 Median Household Income
# 1                Alabama                       53,913
# 2                 Alaska                       77,845
# 3                Arizona                       69,056
# 4               Arkansas                       52,528
# 5             California                       84,907
# 6               Colorado                       82,254
# 7            Connecticut                       83,771
# 8               Delaware                       71,091
# 9   District of Columbia                       90,088
# 10               Florida                       63,062
# 11               Georgia                       66,559
# 12                Hawaii                       84,857
# 13                 Idaho                       66,474
# 14              Illinois                       72,205
# 15               Indiana                       62,743
# 16                  Iowa                       65,600
# ...

# %%
# Merge the first two DataFrames
census_21_22 = pd.merge(census_21_households, census_22_households, on="Label (Grouping)")

# Now merge the result with the third DataFrame
census_21_22_23 = pd.merge(census_21_22, census_23_households, on="Label (Grouping)")

# Check the final merged DataFrame
print(census_21_22_23.head())
# Out:
# 0 Label (Grouping) 2021 Median Household Income 2022 Median Household Income  \
# 0          Alabama                       53,913                       59,674
# 1           Alaska                       77,845                       88,121
# 2          Arizona                       69,056                       74,568
# 3         Arkansas                       52,528                       55,432
# 4       California                       84,907                       91,551
#
# 0 2023 Median Household Income
# 0                       62,212
# 1                       86,631
# 2                       77,315
# 3                       58,700
# 4                       95,521

# %%
census_21_22_23_final = census_21_22_23.rename(columns=lambda col: col.replace('Median income (dollars)Estimate	', ''))

census_21_22_23_final
# Out:
# 0       Label (Grouping) 2021 Median Household Income  \
# 0                Alabama                       53,913
# 1                 Alaska                       77,845
# 2                Arizona                       69,056
# 3               Arkansas                       52,528
# 4             California                       84,907
# 5               Colorado                       82,254
# 6            Connecticut                       83,771
# 7               Delaware                       71,091
# 8   District of Columbia                       90,088
# 9                Florida                       63,062
# 10               Georgia                       66,559
# 11                Hawaii                       84,857
# 12                 Idaho                       66,474
# 13              Illinois                       72,205
# 14               Indiana                       62,743
# 15                  Iowa                       65,600
# ...

# %%
census_21_22_23_final.rename(columns={"Label (Grouping)": "State name"}, inplace=True, errors="ignore")
census_21_22_23_final
# Out:
# 0             State name 2021 Median Household Income  \
# 0                Alabama                       53,913
# 1                 Alaska                       77,845
# 2                Arizona                       69,056
# 3               Arkansas                       52,528
# 4             California                       84,907
# 5               Colorado                       82,254
# 6            Connecticut                       83,771
# 7               Delaware                       71,091
# 8   District of Columbia                       90,088
# 9                Florida                       63,062
# 10               Georgia                       66,559
# 11                Hawaii                       84,857
# 12                 Idaho                       66,474
# 13              Illinois                       72,205
# 14               Indiana                       62,743
# 15                  Iowa                       65,600
# ...
